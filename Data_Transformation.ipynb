# %% [markdown]
# # Data Transformation
#
# Once your data is clean, the next step is to **reshape, reformat, and reorder** it as needed for analysis. Pandas gives you plenty of flexible tools to do this.
#
# ---
#
# ## Sorting & Ranking
#
# ### Sort by Values
#
# ```python
# df.sort_values("Age")                   # Ascending sort
# df.sort_values("Age", ascending=False)  # Descending
# df.sort_values(["Age", "Salary"])       # Sort by multiple columns
# ```
# df.sort_values(["Age", "Salary"]) sorts the DataFrame first by the "Age" column, and if there are ties (i.e., two or more rows with the same "Age"), it will sort by the "Salary" column.
#
# ### Reset Index
# If you want the index to start from 0 and be sequential, you can reset it using reset_index()
# ```python
# df.reset_index(drop=True, inplace=True)  # Reset the index and drop the old index
# ```
# ### Sort by Index
#
# ```python
# df.sort_index()
# ```
# The df.sort_index() function is used to sort the DataFrame based on its index values. If the index is not in a sequential order (e.g., you have dropped rows or performed other operations that change the index), you can use sort_index() to restore it to a sorted order.
# ### Ranking
# The .rank() function in pandas is used to assign ranks to numeric values in a column, like scores or points. By default, it gives the average rank to tied values, which can result in decimal numbers. For example, if two people share the top score, they both get a rank of 1.5. You can customize the ranking behavior using the method parameter. One useful option is method='dense', which assigns the same rank to ties but doesn’t leave gaps in the ranking sequence. This is helpful when you want a clean, consecutive ranking system without skips.
# ```python
# df["Rank"] = df["Score"].rank()                 # Default: average method
# df["Rank"] = df["Score"].rank(method="dense")   # 1, 2, 2, 3
# ```
#
# ---
#
# ## Renaming Columns & Index
#
# ```python
# df.rename(columns={"oldName": "newName"}, inplace=True)
# df.rename(index={0: "row1", 1: "row2"}, inplace=True)
# ```
#
# To rename all columns:
#
# ```python
# df.columns = ["Name", "Age", "City"]
# ```
#
# ---
#
# ## Changing Column Order
#
# Just pass a new list of column names:
#
# ```python
# df = df[["City", "Name", "Age"]]   # Reorder as desired
# ```
#
# You can also move one column to the front:
#
# ```python
# cols = ["Name"] + [col for col in df.columns if col != "Name"]
# df = df[cols]
# ```
#
# ---
#
#
#
# ## Summary
#
# - Sort, rank, and rename to prepare your data
# - Reordering and reshaping are key for EDA and visualization

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#                  Actor                      Film    Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023.0           Action
# 1          Salman Khan           Tiger Zinda Hai  2017.0           Action
# 2           Aamir Khan                    Dangal  2016.0        Biography
# 3        Ranbir Kapoor                Brahmastra  2022.0          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018.0       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018.0         Thriller
# 6        Rajkummar Rao                     Stree  2018.0    Horror Comedy
# 7       Hrithik Roshan                       War  2019.0           Action
# 8         Akshay Kumar                Good Newwz  2019.0           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022.0    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017.0  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019.0           Action
# 12      //djskdladjkdv                       NaN     NaN              NaN
#
#     BoxOffice(INR Crore)  IMDb
# 0                 1050.0   7.2
# 1                  565.0   6.0
# 2                 2024.0   8.4
# 3                  431.0   5.6
# 4                  585.0   7.0
# 5                  111.0   8.3
# 6                  180.0   7.5
# 7                  475.0   6.5
# 8                  318.0   7.0
# 9                  266.0   5.9
# 10                 201.0   6.1
# 11                 342.0   8.2
# 12                   NaN   NaN

# %%
df.sort_values("Year")
# Out:
#                  Actor                      Film    Year            Genre  \
# 2           Aamir Khan                    Dangal  2016.0        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017.0           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017.0  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018.0       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018.0         Thriller
# 6        Rajkummar Rao                     Stree  2018.0    Horror Comedy
# 7       Hrithik Roshan                       War  2019.0           Action
# 8         Akshay Kumar                Good Newwz  2019.0           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019.0           Action
# 3        Ranbir Kapoor                Brahmastra  2022.0          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022.0    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023.0           Action
# 12      //djskdladjkdv                       NaN     NaN              NaN
#
#     BoxOffice(INR Crore)  IMDb
# 2                 2024.0   8.4
# 1                  565.0   6.0
# 10                 201.0   6.1
# 4                  585.0   7.0
# 5                  111.0   8.3
# 6                  180.0   7.5
# 7                  475.0   6.5
# 8                  318.0   7.0
# 11                 342.0   8.2
# 3                  431.0   5.6
# 9                  266.0   5.9
# 0                 1050.0   7.2
# 12                   NaN   NaN

# %%
df.sort_values("Year", ascending=False)
# Out:
#                  Actor                      Film    Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023.0           Action
# 3        Ranbir Kapoor                Brahmastra  2022.0          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022.0    Horror Comedy
# 7       Hrithik Roshan                       War  2019.0           Action
# 8         Akshay Kumar                Good Newwz  2019.0           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019.0           Action
# 4        Ranveer Singh                 Padmaavat  2018.0       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018.0         Thriller
# 6        Rajkummar Rao                     Stree  2018.0    Horror Comedy
# 1          Salman Khan           Tiger Zinda Hai  2017.0           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017.0  Romantic Comedy
# 2           Aamir Khan                    Dangal  2016.0        Biography
# 12      //djskdladjkdv                       NaN     NaN              NaN
#
#     BoxOffice(INR Crore)  IMDb
# 0                 1050.0   7.2
# 3                  431.0   5.6
# 9                  266.0   5.9
# 7                  475.0   6.5
# 8                  318.0   7.0
# 11                 342.0   8.2
# 4                  585.0   7.0
# 5                  111.0   8.3
# 6                  180.0   7.5
# 1                  565.0   6.0
# 10                 201.0   6.1
# 2                 2024.0   8.4
# 12                   NaN   NaN

# %%
df2 = df.sort_values(["Year", "IMDb"]).copy()

# %%
df2
# Out:
#                  Actor                      Film    Year            Genre  \
# 2           Aamir Khan                    Dangal  2016.0        Biography
# 1          Salman Khan           Tiger Zinda Hai  2017.0           Action
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017.0  Romantic Comedy
# 4        Ranveer Singh                 Padmaavat  2018.0       Historical
# 6        Rajkummar Rao                     Stree  2018.0    Horror Comedy
# 5   Ayushmann Khurrana                 Andhadhun  2018.0         Thriller
# 7       Hrithik Roshan                       War  2019.0           Action
# 8         Akshay Kumar                Good Newwz  2019.0           Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019.0           Action
# 3        Ranbir Kapoor                Brahmastra  2022.0          Fantasy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022.0    Horror Comedy
# 0       Shah Rukh Khan                   Pathaan  2023.0           Action
# 12      //djskdladjkdv                       NaN     NaN              NaN
#
#     BoxOffice(INR Crore)  IMDb
# 2                 2024.0   8.4
# 1                  565.0   6.0
# 10                 201.0   6.1
# 4                  585.0   7.0
# 6                  180.0   7.5
# 5                  111.0   8.3
# 7                  475.0   6.5
# 8                  318.0   7.0
# 11                 342.0   8.2
# 3                  431.0   5.6
# 9                  266.0   5.9
# 0                 1050.0   7.2
# 12                   NaN   NaN

# %%
df2.sort_index()
# Out:
#                  Actor                      Film    Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023.0           Action
# 1          Salman Khan           Tiger Zinda Hai  2017.0           Action
# 2           Aamir Khan                    Dangal  2016.0        Biography
# 3        Ranbir Kapoor                Brahmastra  2022.0          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018.0       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018.0         Thriller
# 6        Rajkummar Rao                     Stree  2018.0    Horror Comedy
# 7       Hrithik Roshan                       War  2019.0           Action
# 8         Akshay Kumar                Good Newwz  2019.0           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022.0    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017.0  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019.0           Action
# 12      //djskdladjkdv                       NaN     NaN              NaN
#
#     BoxOffice(INR Crore)  IMDb
# 0                 1050.0   7.2
# 1                  565.0   6.0
# 2                 2024.0   8.4
# 3                  431.0   5.6
# 4                  585.0   7.0
# 5                  111.0   8.3
# 6                  180.0   7.5
# 7                  475.0   6.5
# 8                  318.0   7.0
# 9                  266.0   5.9
# 10                 201.0   6.1
# 11                 342.0   8.2
# 12                   NaN   NaN

# %%
df = df[["Film", "Actor", "Year", "Genre", "IMDb", "BoxOffice(INR Crore)"]]

# %%
df
# Out:
#                         Film               Actor    Year            Genre  \
# 0                    Pathaan      Shah Rukh Khan  2023.0           Action
# 1            Tiger Zinda Hai         Salman Khan  2017.0           Action
# 2                     Dangal          Aamir Khan  2016.0        Biography
# 3                 Brahmastra       Ranbir Kapoor  2022.0          Fantasy
# 4                  Padmaavat       Ranveer Singh  2018.0       Historical
# 5                  Andhadhun  Ayushmann Khurrana  2018.0         Thriller
# 6                      Stree       Rajkummar Rao  2018.0    Horror Comedy
# 7                        War      Hrithik Roshan  2019.0           Action
# 8                 Good Newwz        Akshay Kumar  2019.0           Comedy
# 9          Bhool Bhulaiyaa 2       Kartik Aaryan  2022.0    Horror Comedy
# 10     Badrinath Ki Dulhania        Varun Dhawan  2017.0  Romantic Comedy
# 11  Uri: The Surgical Strike       Vicky Kaushal  2019.0           Action
# 12                       NaN      //djskdladjkdv     NaN              NaN
#
#     IMDb  BoxOffice(INR Crore)
# 0    7.2                1050.0
# 1    6.0                 565.0
# 2    8.4                2024.0
# 3    5.6                 431.0
# 4    7.0                 585.0
# 5    8.3                 111.0
# 6    7.5                 180.0
# 7    6.5                 475.0
# 8    7.0                 318.0
# 9    5.9                 266.0
# 10   6.1                 201.0
# 11   8.2                 342.0
# 12   NaN                   NaN
