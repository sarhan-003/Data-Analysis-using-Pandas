# %% [markdown]
# # Reading & Writing Files in Pandas
#
# ## CSV Files
#
# ### Read CSV
# ```python
# df = pd.read_csv("data.csv")
# ```
#
# Options:
# ```python
# pd.read_csv("data.csv", usecols=["Name", "Age"], nrows=10)
# ```
#
# ### Write CSV
# ```python
# df.to_csv("output.csv", index=False)
# ```
#
# ---
#
# ## Excel Files
#
# ### Read Excel
# ```python
# df = pd.read_excel("data.xlsx")
# ```
#
# Options:
# ```python
# pd.read_excel("data.xlsx", sheet_name="Sales")
# ```
#
# ### Write Excel
# ```python
# df.to_excel("output.xlsx", index=False)
# ```
#
# Multiple sheets:
# ```python
# with pd.ExcelWriter("report.xlsx") as writer:
#     df1.to_excel(writer, sheet_name="Summary", index=False)
#     df2.to_excel(writer, sheet_name="Details", index=False)
# ```
#
# ---
#
# ## JSON Files
#
# ### Read JSON
# ```python
# df = pd.read_json("data.json")
# ```
#
#
# ## Summary
#
# - `read_*` and `to_*` methods for CSV, Excel, JSON
# - Use `sheet_name` for Excel

# %%
import pandas as pd

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#                  Actor                      Film    Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023.0           Action
# 1          Salman Khan           Tiger Zinda Hai  2017.0           Action
# 2           Aamir Khan                    Dangal  2016.0        Biography
# 3        Ranbir Kapoor                Brahmastra  2022.0          Fantasy
# 4        Ranveer Singh                 Padmaavat  2018.0       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018.0         Thriller
# 6        Rajkummar Rao                     Stree  2018.0    Horror Comedy
# 7       Hrithik Roshan                       War  2019.0           Action
# 8         Akshay Kumar                Good Newwz  2019.0           Comedy
# 9        Kartik Aaryan         Bhool Bhulaiyaa 2  2022.0    Horror Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017.0  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019.0           Action
# 12      //djskdladjkdv                       NaN     NaN              NaN
#
#     BoxOffice(INR Crore)  IMDb
# 0                 1050.0   7.2
# 1                  565.0   6.0
# 2                 2024.0   8.4
# 3                  431.0   5.6
# 4                  585.0   7.0
# 5                  111.0   8.3
# 6                  180.0   7.5
# 7                  475.0   6.5
# 8                  318.0   7.0
# 9                  266.0   5.9
# 10                 201.0   6.1
# 11                 342.0   8.2
# 12                   NaN   NaN

# %%
df = df[df['IMDb']>6.0]

# %%
df
# Out:
#                  Actor                      Film    Year            Genre  \
# 0       Shah Rukh Khan                   Pathaan  2023.0           Action
# 2           Aamir Khan                    Dangal  2016.0        Biography
# 4        Ranveer Singh                 Padmaavat  2018.0       Historical
# 5   Ayushmann Khurrana                 Andhadhun  2018.0         Thriller
# 6        Rajkummar Rao                     Stree  2018.0    Horror Comedy
# 7       Hrithik Roshan                       War  2019.0           Action
# 8         Akshay Kumar                Good Newwz  2019.0           Comedy
# 10        Varun Dhawan     Badrinath Ki Dulhania  2017.0  Romantic Comedy
# 11       Vicky Kaushal  Uri: The Surgical Strike  2019.0           Action
#
#     BoxOffice(INR Crore)  IMDb
# 0                 1050.0   7.2
# 2                 2024.0   8.4
# 4                  585.0   7.0
# 5                  111.0   8.3
# 6                  180.0   7.5
# 7                  475.0   6.5
# 8                  318.0   7.0
# 10                 201.0   6.1
# 11                 342.0   8.2

# %%
df.to_csv("data_updated.csv", index=False)

# %%
df = pd.read_json("my.json")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = pd.read_json("my.json")
#
# File c:\Users\Sarhan Bakarman\anaconda3\Lib\site-packages\pandas\io\json\_json.py:791, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     788 if convert_axes is None and orient != "table":
#     789     convert_axes = True
# --> 791 json_reader = JsonReader(
#     792     path_or_buf,
#     793     orient=orient,
#     794     typ=typ,
#     795     dtype=dtype,
#     796     convert_axes=convert_axes,
#     797     convert_dates=convert_dates,
#     798     keep_default_dates=keep_default_dates,
#     799     precise_float=precise_float,
#     800     date_unit=date_unit,
#     801     encoding=encoding,
#     802     lines=lines,
#     803     chunksize=chunksize,
#     804     compression=compression,
#     805     nrows=nrows,
#     806     storage_options=storage_options,
#     807     encoding_errors=encoding_errors,
#     808     dtype_backend=dtype_backend,
#     809     engine=engine,
#     810 )
#     812 if chunksize:
#     813     return json_reader
#
# File c:\Users\Sarhan Bakarman\anaconda3\Lib\site-packages\pandas\io\json\_json.py:904, in JsonReader.__init__(self, filepath_or_buffer, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, lines, chunksize, compression, nrows, storage_options, encoding_errors, dtype_backend, engine)
#     902     self.data = filepath_or_buffer
#     903 elif self.engine == "ujson":
# --> 904     data = self._get_data_from_filepath(filepath_or_buffer)
#     905     self.data = self._preprocess_data(data)
#
# File c:\Users\Sarhan Bakarman\anaconda3\Lib\site-packages\pandas\io\json\_json.py:960, in JsonReader._get_data_from_filepath(self, filepath_or_buffer)
#     952     filepath_or_buffer = self.handles.handle
#     953 elif (
#     954     isinstance(filepath_or_buffer, str)
#     955     and filepath_or_buffer.lower().endswith(
#    (...)    958     and not file_exists(filepath_or_buffer)
#     959 ):
# --> 960     raise FileNotFoundError(f"File {filepath_or_buffer} does not exist")
#     961 else:
#     962     warnings.warn(
#     963         "Passing literal json to 'read_json' is deprecated and "
#     964         "will be removed in a future version. To read from a "
#    (...)    967         stacklevel=find_stack_level(),
#     968     )
#
# FileNotFoundError: File my.json does not exist

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Actor                 9 non-null      object
#  1   Film                  9 non-null      object
#  2   Year                  9 non-null      float64
#  3   Genre                 9 non-null      object
#  4   BoxOffice(INR Crore)  9 non-null      float64
#  5   IMDb                  9 non-null      float64
# dtypes: float64(3), object(3)
# memory usage: 504.0+ bytes

# %%
data = [
    {"id": 1, "name": "Alice", "address": {"city": "Delhi", "zipcode": "110001"}},
    {"id": 2, "name": "Bob", "address": {"city": "Mumbai", "zipcode": "400001"}}
]
